# %%
import numpy as np
import math
import matplotlib.pyplot as plt

o1 = np.arange(-10,10,0.05)
o2 = 0.2;
o3 = 0.2;
y = [[] for _ in range(400)]

for i in np.arange(400):
    y[i] = np.exp(o1[i]) / np.sum(np.exp(o1[i]) + np.exp(o2) + np.exp(o3))

plt.plot(o1,y)
